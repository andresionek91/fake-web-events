# %%
import pandas as pd
from fake_web_events.simulation import Simulation
import pprint

# %%
pp = pprint.PrettyPrinter(indent=4)


simulation = Simulation(user_pool_size=1, sessions_per_day=1)
events = simulation.run(duration_seconds=6)

for event in events:
    pp.pprint(event)
# Out:
# ['Windows', 'MacOS', 'Linux', 'Android', 'iOS'] dict_values([0.1, 0.15, 0.05, 0.3, 0.4])
# ['Chrome', 'Firefox', 'InternetExplorer', 'Safari', 'Opera'] dict_values([0.5, 0.25, 0.05, 0.1, 0.1])
# ['comedy', 'horror', 'family', 'romance', 'action', 'mystery', 'kids'] dict_values([0.18, 0.14, 0.16, 0.19, 0.12, 0.11, 0.09])
# ['ad_1', 'ad_2', 'ad_3', 'ad_4', 'ad_5'] dict_values([0.05, 0.3, 0.2, 0.25, 0.2])
# ['campaign_1', 'campaign_2'] dict_values([0.8, 0.2])
# ['cpc', 'affiliate', 'organic', 'social'] dict_values([0.25, 0.1, 0.4, 0.25])
# ['google', 'facebook', 'bing', 'instagram', 'mailchimp'] dict_values([0.15, 0.3, 0.05, 0.2, 0.3])
# ['home', 'brooklyn_99', 'law_order'] dict_values([0.6, 0.25, 0.15])
# ['hd', 'sd'] dict_values([0.73, 0.27])
# ...
